# %%
# L8_P2 15-04-2026

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 1/0
#
# ZeroDivisionError: division by zero

# %%
li = [print(i**2) for i in range(5)]
# Out:
# 0
# 1
# 4
# 9
# 16

# %%
li
# Out:
# [None, None, None, None, None]

# %%
for i in range(5):
    print(i)
    i += 9999
    print(i)
# Out:
# 0
# 9999
# 1
# 10000
# 2
# 10001
# 3
# 10002
# 4
# 10003

# %%
for i in range(5):
    i += 9999

# %%
def xxx(x):
    return x**2

# %%
# mvp1
def xxx(x):
    return x**2

# test 1 

# mvp2
def xxx(x):
    if .....:
        pass
        1
    else:
        pass
        ....1
    return x**2

# test 1 Failed
# test 2 ok
# test 3 Failed
    
# mvp3
def xxx(x):
    if .....:
        pass
        1
    else:
        pass
        ....1
    if ....:
        pass
        2344433553
    else:
        pass
        .....3452326
    return x**2
# test 1 ok
# test 2 ok
# test 3 ok
# test 4 ok
# test 5 ok

# %%
# x <= 100000 
# x >= 23432134567

def xxx(x):
    return x**2

# %%
def test_xxx_pos_numbers():
    # test 1 
    # test 2
# Out:
#   Cell In[10], line 3
#     # test 2
#             ^
# _IncompleteInputError: incomplete input
