# %%
li = [1,2,3,4]

# %%
print(li[2])
# Out:
# 3

# %%
li[2] = 77

# %%
li
# Out:
# [1, 2, 77, 4]

# %%
li.insert(2, 555)

# %%
li
# Out:
# [1, 2, 555, 77, 4]

# %%
li[2] = 0

# %%
li
# Out:
# [1, 2, 0, 77, 4]

# %%
# 27-03-2026

# %%
# copy

# %%
li
# Out:
# [1, 2, 0, 77, 4]

# %%
newli = li.copy()

# %%
li
# Out:
# [1, 2, 0, 77, 4]

# %%
newli
# Out:
# [1, 2, 0, 77, 4]

# %%
newli[1] = 9999

# %%
newli
# Out:
# [1, 9999, 0, 77, 4]

# %%
li
# Out:
# [1, 2, 0, 77, 4]

# %%
help(id)
# Out:
# Help on built-in function id in module builtins:
#
# id(obj, /)
#     Return the identity of an object.
#
#     This is guaranteed to be unique among simultaneously existing objects.
#     (CPython uses the object's memory address.)

# %%
a = 1
b = 1

# %%
id(a)
# Out:
# 140726088278952

# %%
id(b)
# Out:
# 140726088278952

# %%
b = 999

# %%
id(b)
# Out:
# 2300178397616

# %%
id(a)
# Out:
# 140726088278952

# %%
li
# Out:
# [1, 2, 0, 77, 4]

# %%
li2 = li

# %%
li2
# Out:
# [1, 2, 0, 77, 4]

# %%
id(li)
# Out:
# 2300177753984

# %%
id(li2)
# Out:
# 2300177753984

# %%
li[0] = 888

# %%
id(li)
# Out:
# 2300177753984

# %%
id(li2)
# Out:
# 2300177753984

# %%
li
# Out:
# [888, 2, 0, 77, 4]

# %%
li2
# Out:
# [888, 2, 0, 77, 4]

# %%
li = li2 # плохо, потому что через 2 имени можно менять один и тот же набор значение

# %%
li = li2.copy # хорошо, так как 2 имени указывают на разные наборы значений

# %%
li
# Out:
# <function list.copy()>

# %%
li2
# Out:
# [888, 2, 0, 77, 4]

# %%
li2.pop()
# Out:
# 4

# %%
li2
# Out:
# [888, 2, 0, 77]

# %%
removedVal = li2.pop

# %%
removedVal
# Out:
# <function list.pop(index=-1, /)>

# %%
li2.pop(1)
# Out:
# 2

# %%
li2
# Out:
# [888, 0, 77]

# %%
del li2[-1]

# %%
li2
# Out:
# [888, 0]

# %%
li2.clear()

# %%
li2
# Out:
# []

# %%
len(li2)
# Out:
# 0

# %%
li = [1,2,3,4,5,6,7]

# %%
# for in range print input append result sort revers len

# %%
n = int(input("Сколько чисел нужно?"))
# Out:
# Сколько чисел нужно? 6

# %%
n
# Out:
# 6

# %%
type(n)
# Out:
# int

# %%
n = int(input("Сколько чисел нужно?")) 
userlist = []

for i in range(n):
    userlist.append(int(input("дай мне int-->")))
else:
    resultS = sum(userlist)
    print(userlist)
    userlist.sort()
    print(userlist)
    userlist.reverse()
    print(userlist)
    print("len=", len(userlist))
    print("sum=", resultS)
# Out:
# Сколько чисел нужно? 5
# дай мне int--> 35643
# дай мне int--> 3543247
# дай мне int--> 2343
# дай мне int--> 2343
# дай мне int--> 2254
# [35643, 3543247, 2343, 2343, 2254]
# [2254, 2343, 2343, 35643, 3543247]
# [3543247, 35643, 2343, 2343, 2254]
# len= 5
# sum= 3585830

# %%
# by value

# %%
li = [1,2,3,4,5,6,7,8]

# %%
for value in li:
    print(value, end=" ")
# Out:
# 1 2 3 4 5 6 7 8

# %%
li = [1,2,3,4]

# %%
li[0], li[1],li[2], li[3]
# Out:
# (1, 2, 3, 4)

# %%
range(x)  -- 0 to x не включительно

# %%
len() -- 4

# %%
for index in range(len(li)):
    print("index", index)
    print("^ value ^", li[index])
# Out:
# index 0
# ^ value ^ 1
# index 1
# ^ value ^ 2
# index 2
# ^ value ^ 3
# index 3
# ^ value ^ 4

# %%
for index in range(len(li)):
    print("index", index)
    print("^ value ^", li[index])
# Out:
# index 0
# ^ value ^ 1
# index 1
# ^ value ^ 2
# index 2
# ^ value ^ 3
# index 3
# ^ value ^ 4

# %%
li = ["блокнот", "ручка", "карандаш"]

# %%
counter = 0
for i in li:
    print(counter)
    print(i, end=" ")
    counter += 1
# Out:
# 0
# блокнот 1
# ручка 2
# карандаш

# %%
li = ["блокнот", "ручка", "карандаш"]

# %%
for i, value in enumerate(li):
    print(i, value, end=" ")
# Out:
# 0 блокнот 1 ручка 2 карандаш

# %%
help(zip)
# Out:
# Help on class zip in module builtins:
#
# class zip(object)
#  |  zip(*iterables, strict=False)
#  |
#  |  The zip object yields n-length tuples, where n is the number of iterables
#  |  passed as positional arguments to zip().  The i-th element in every tuple
#  |  comes from the i-th iterable argument to zip().  This continues until the
#  |  shortest argument is exhausted.
#  |
#  |  If strict is true and one of the arguments is exhausted before the others,
#  |  raise a ValueError.
#  |
#  |     >>> list(zip('abcdefg', range(3), range(4)))
#  |     [('a', 0, 0), ('b', 1, 1), ('c', 2, 2)]
#  |
#  |  Methods defined here:
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __next__(self, /)
#  |      Implement next(self).
#  |
#  |  __reduce__(self, /)
#  |      Return state information for pickling.
#  |
#  |  __setstate__(self, object, /)
# ...

# %%
currency = ["BYN", "RUB", "USD", "EUR"]

# %%
country = ["Belarus", "Russia", "France", "USA"]

# %%
zip(currency,country)

# %%
list(zip(currency,country))
# Out:
# [('BYN', 'Belarus'), ('RUB', 'Russia'), ('USD', 'France'), ('EUR', 'USA')]

# %%
# sort ?

# %%
list
0 1 2 3 4 5 - index
5 6 9 2 1 4 - value

# 1 2 4 5 6 9 - цель

# %%
li[0] 5
li[1] 6
5 > 6 - False

li[1] 6
li[2] 9
6 > 9 - False

li[2] 9
li[3] 2
9 > 2 - True

temp = li[2] 9
li[2] = li[3] 2
li[3] = temp 9

# list
# 0 1 2 3 4 5 - index
# 5 6 2 9 1 4 - value

li[3] 9
li[4] 1
9 > 1 - True

temp = li[3] 9
li[3] = li[4] 1
li[4] = temp 9

# list
# 0 1 2 3 4 5 - index
# 5 6 2 1 9 4 - value

li[4] 9
li[5] 4
9 > 4 - True

temp = li[4] 9
li[4] = li[5] 4
li[5] = temp 9

# list
# 0 1 2 3 4 5 - index
# 5 6 2 1 4 9 - value

# %%
li =[1,3,5,2]

# %%
# 5 - 2
# 2 - 3

# %%
temp = li[2]

# %%
temp
# Out:
# 5

# %%
li[2] = li[3]

# %%
li
# Out:
# [1, 3, 2, 2]

# %%
li[3] = temp

# %%
li
# Out:
# [1, 3, 2, 5]

# %%
temp = li[1]
li[1] = li[2]
li[2] = temp

# %%
li
# Out:
# [1, 2, 3, 5]

# %%
li =[1,3,5,2]

# %%
li
# Out:
# [1, 3, 5, 2]

# %%
li[2], li[3] = li[3], li[2]

# %%
li
# Out:
# [1, 3, 2, 5]

# %%
li[1], li[2] = li[2], li[1]

# %%
li
# Out:
# [1, 2, 3, 5]

# %%
# slice

# %%
li = [3,4,65,6,542]

# %%
# list
# цель  newli [4,65,6]
# [index] - НЕ позволит сделать срез
# [stratIndex:endIndex]

# [3,4,65,6,542]
# [4,65,6]
# stratIndex = 2 
# endIndex = 4+1=5

# li[2:5]

# %%
li[2:5]
# Out:
# [65, 6, 542]

# %%
li
# Out:
# [3, 4, 65, 6, 542]

# %%
li[:3]
# Out:
# [3, 4, 65]

# %%
li[3:]
# Out:
# [6, 542]

# %%
li[:]
# Out:
# [3, 4, 65, 6, 542]

# %%
# есть ли то, что я ищу, внутри списка?

# %%
s = "fffff"

# %%
s
# Out:
# 'fffff'

# %%
"F" in s
# Out:
# False

# %%
"f" in s
# Out:
# True

# %%
for i in s:
    print(i, end=" ")
# Out:
# f f f f f

# %%
li = [3,4,65,6,542]

# %%
s in li
# Out:
# False

# %%
542 in li
# Out:
# True

# %%
li
# Out:
# [3, 4, 65, 6, 542]

# %%
sum(li)
# Out:
# 620

# %%
result = 0

# %%
for val in li:
    result += val

# %%
result
# Out:
# 620

# %%
li
# Out:
# [3, 4, 65, 6, 542]

# %%
li = [1,2,3,3,4,4,5,65,66,65]

# %%
li
# Out:
# [1, 2, 3, 3, 4, 4, 5, 65, 66, 65]

# %%
se = {1, 2, 3, 3, 4, 4, 5, 65, 66, 65}

# %%
se
# Out:
# {1, 2, 3, 4, 5, 65, 66}

# %%
newset = set(li)

# %%
newset
# Out:
# {1, 2, 3, 4, 5, 65, 66}

# %%
li
# Out:
# [1, 2, 3, 3, 4, 4, 5, 65, 66, 65]

# %%
li = list(set(li))

# %%
li
# Out:
# [1, 2, 3, 4, 5, 65, 66]

# %%
se = set()

# %%
se
# Out:
# set()

# %%
type(se)
# Out:
# set

# %%
se ={}

# %%
type(se)
# Out:
# dict

# %%
se = {1,2,3}

# %%
se.add(33333)

# %%
se
# Out:
# {1, 2, 3, 33333}

# %%
se.add(3)

# %%
se
# Out:
# {1, 2, 3, 33333}

# %%
se.remove(2)

# %%
se
# Out:
# {1, 3, 33333}

# %%
se.remove(222)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[160], line 1
# ----> 1 se.remove(222)
#
# KeyError: 222

# %%
se.discard(1)

# %%
se
# Out:
# {3, 33333}

# %%
se.discard(222)

# %%
se
# Out:
# {3, 33333}

# %%
for i in se:
    print(i)
# Out:
# 3
# 33333

# %%
len(se)
# Out:
# 2

# %%
se = {1,2,3,4, "33", "!"}

# %%
se
# Out:
# {'!', 1, 2, 3, '33', 4}

# %%
se[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[263], line 1
# ----> 1 se[1]
#
# TypeError: 'set' object is not subscriptable

# %%
st = "dgwyufe"

# %%
list(st)
# Out:
# ['d', 'g', 'w', 'y', 'u', 'f', 'e']

# %%
set(st)
# Out:
# {'d', 'e', 'f', 'g', 'u', 'w', 'y'}

# %%
# Lab 3.4
my_list = [1, 2, 4, 4, 1, 4, 2, 6, 2, 9]

# %%
my_list = list(set(my_list))

# %%
my_list
# Out:
# [1, 2, 4, 6, 9]

# %%
# однострочники

# %%
st = "euefuefgfgeuergrgdfjjssy"

# %%
li = []

# %%
for char in st:
    if char in "aeouyqi":
        li.append(char.upper())
    else:
        li.append(char*2)

# %%
print(li)
# Out:
# ['E', 'U', 'E', 'ff', 'U', 'E', 'ff', 'gg', 'ff', 'gg', 'E', 'U', 'E', 'rr', 'gg', 'rr', 'gg', 'dd', 'ff', 'jj', 'jj', 'ss', 'ss', 'Y', 'E', 'U', 'E', 'ff', 'U', 'E', 'ff', 'gg', 'ff', 'gg', 'E', 'U', 'E', 'rr', 'gg', 'rr', 'gg', 'dd', 'ff', 'jj', 'jj', 'ss', 'ss', 'Y']

# %%
st = "euefuefgfgeuergrgdfjjssy"

# %%
for char in st:
    if char in "aeouyqi":
        li.append(char.upper())
    else:
        li.append(char*2)

[char.upper() for char in st if char in "aeouyqi" else (char*2)]

# %%
li =[]
for char in st:
    if char in "aeouyqi":
        li.append(char.upper())
print(li)

# %%
r = [char.upper() for char in st if char not in "aeouyqi"]

# %%
print(r)
# Out:
# ['F', 'F', 'G', 'F', 'G', 'R', 'G', 'R', 'G', 'D', 'F', 'J', 'J', 'S', 'S']

# %%
userlist = [int(input("-->"))**2/66+9 for i in range(int(input("Сколько чисел?")))]
# Out:
# Сколько чисел? 3
# --> 5
# --> 3
# --> 2

# %%
userlist
# Out:
# [9.378787878787879, 9.136363636363637, 9.06060606060606]

# %%
# 1 4 7 9 10

# %%
sep = " "

# %%
number = input()
# Out:
#  1 2 3 4 5

# %%
number
# Out:
# '1 2 3 4 5'

# %%
number.split(sep)
# Out:
# ['1', '2', '3', '4', '5']

# %%
[int(val) for val in number.split(sep)]
# Out:
# [1, 2, 3, 4, 5]

# %%
# list in list

# %%
 li = [1,2,3,4,5]

# %%
li[2]
# Out:
# 3

# %%
li = [[1,], [2,], [3,], [4,]]

# %%
li[0]
# Out:
# [1]

# %%
li = [[1,2,3], [2,], [3,], [4,]]

# %%
li[0]
# Out:
# [1, 2, 3]

# %%
li[2]
# Out:
# [3]

# %%
li[0][1]
# Out:
# 2

# %%
li[0][2]
# Out:
# 3
